# %% [markdown]
# # 11 - Valutazione su ASVspoof 2021 DF: ablazione P / Wf / E / PWfE
#
# Valutazione dei modelli gia' addestrati su ASVspoof 2019 LA sulla partizione di valutazione di
# ASVspoof 2021 Deepfake. Si estraggono le caratteristiche sui
# file del DF, si applicano le trasformazioni salvate in addestramento e si calcolano i punteggi.
#
# **Configurazioni valutate**
# - **P**: solo ramo prosodico, variante D (notebook 06.1, `model_D_seed0.pt`);
# - **Wf**: solo ramo Whisper a livello di file (notebook 09, `model_Wf_seed0.pt`);
# - **E**: solo ramo ECAPA-TDNN (notebook 09, `model_E_seed0.pt`);
# - **PWfE**: architettura completa con fusione tardiva (notebook 10, `model_PWfE_seed0.pt`).
#
# Whisper e' usato **solo a livello di file**: i frame non vengono ne' salvati ne' utilizzati.
#
# **Tre fasi, da eseguire in sessioni distinte** (si imposta `FASE` nella cella di configurazione):
#
# 1. `"ptm"` - estrazione di `whisper_mean` (512) ed ECAPA (192).
# 2. `"prosodia"` - estrazione delle 8 caratteristiche Praat per finestre da 200 ms. Richiede CPU
#    multi-core.
# 3. `"inferenza"` - carica le caratteristiche prodotte dalle due fasi precedenti, applica i modelli e
#    calcola le metriche.
#
# Entrambe le fasi di estrazione scrivono a blocchi e **riprendono da dove si erano fermate**: dopo
# un'interruzione basta rieseguire la stessa fase.
#
# **Metrica**: EER con l'implementazione ufficiale ASVspoof 2021 (`eval_metrics.py`, stesso SHA256 dei
# notebook precedenti). Oltre all'EER complessivo si riportano le scomposizioni consentite dai
# meta-dati del DF: per **condizione di compressione** (nove condizioni, da `nocodec` a `oggm4a`), per
# **sorgente** (`asvspoof`, `vcc2018`, `vcc2020`), per **attacco** e per **tipo di vocoder**.

# %%
import os, re, sys, json, math, time, subprocess
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence, PackedSequence
import librosa


# --------------------------------------------------------------------------------
# FASE: "ptm" | "prosodia" | "inferenza"
FASE = os.environ.get("FASE", "prosodia")

# Audio del DF (cartella che contiene i file .flac, anche annidati) e chiavi ufficiali.
DF_AUDIO_DIR = "/kaggle/input/datasets/angelopaldino/evalzenodo"
DF_KEYS      = "/kaggle/input/datasets/angelopaldino/df-keys/CM/trial_metadata.txt"

SUBSETS = ["eval"]

# Cartelle prodotte dalle fasi di estrazione (stesso percorso per tutte e tre le fasi).
OUT_DIR   = Path(os.environ.get("OUT_DIR", "/kaggle/working/df2021"))

PTM_DIR_IN  = Path("/kaggle/input/datasets/angelopaldino/test-ptm1000/df2021/ptm")
PROS_DIR_IN = Path("/kaggle/input/datasets/angelopaldino/test-prosodia/df2021/prosodia")  

PTM_DIR   = OUT_DIR / "ptm"          # whisper_mean + ecapa, a blocchi
PROS_DIR  = OUT_DIR / "prosodia"     # finestre Praat, a blocchi



if FASE == "ptm":
    PTM_DIR = PTM_DIR_IN
    PROS_DIR = PROS_DIR_IN
else:
    PTM_DIR = OUT_DIR / "ptm"
    PROS_DIR = OUT_DIR / "prosodia"

# Checkpoint e statistiche di preprocessing salvate in addestramento.
CKPT = {
    "P": "/kaggle/input/datasets/angelopaldino/models/Modelli/model_D_seed0.pt",
    "Wf": "/kaggle/input/datasets/angelopaldino/models/Modelli/model_Wf_seed0.pt",
    "E": "/kaggle/input/datasets/angelopaldino/models/Modelli/model_E_seed0.pt",
    "PWfE": "/kaggle/input/datasets/angelopaldino/models/Modelli/model_PWfE_seed0.pt"
}
PREPROC_PROSODIA = "/kaggle/input/datasets/angelopaldino/models/Modelli/preproc_prosody.json"
STANDARDIZER     = "/kaggle/input/datasets/angelopaldino/models/Modelli/standardizer.json"

# --------------------------------------------------------------------------------
WHISPER_MODEL = "openai/whisper-base"
ECAPA_MODEL   = "speechbrain/spkrec-ecapa-voxceleb"
SR, HOP_SAMPLES, MAX_FRAMES = 16000, 320, 1500
WHISPER_BATCH = int(os.environ.get("WHISPER_BATCH", 16))
ECAPA_BATCH   = int(os.environ.get("ECAPA_BATCH", 16))
SHARD_FILES   = int(os.environ.get("SHARD_FILES", 2000))     # fase ptm
CHUNK_PROS    = int(os.environ.get("CHUNK_PROS", 1000))      # fase prosodia

# Parametri Praat, identici al notebook 04
PITCH_FLOOR, PITCH_CEILING = 75.0, 500.0
MAX_CANDIDATES, VERY_ACCURATE, VOICING_THRESHOLD, TIME_STEP = 15, "no", 0.45, 0.0
PERIOD_FLOOR, PERIOD_CEILING = 0.8 / PITCH_CEILING, 1.25 / PITCH_FLOOR
MAX_PERIOD_FACTOR, MAX_AMPLITUDE_FACTOR = 1.3, 1.6
HNR_TIME_STEP, HNR_SILENCE, HNR_PERIODS = 0.01, 0.1, 1.0
WINDOW_S = 0.2
CFG_STANDARD = {"silence_threshold": 0.03, "octave_cost": 0.01,
                "octave_jump_cost": 0.35, "voiced_unvoiced_cost": 0.14}
FEATURES = ["f0_mean", "f0_std", "jitter_local", "shimmer_local",
            "hnr_mean", "hnr_std", "intensity_mean", "intensity_std"]

D_WHISPER, D_ECAPA, EMB_DIM, DROPOUT = 512, 192, 50, 0.2
N_BLOCKS_D = 2                 # variante prosodica D: 8 feature + delta
EVAL_BATCH = 256
MIN_PER_CLASSE = 10           # soglia sotto la quale l'EER di un gruppo non viene calcolato

OUT_DIR.mkdir(parents=True, exist_ok=True)

if FASE != "inferenza":
    PTM_DIR.mkdir(parents=True, exist_ok=True)
    PROS_DIR.mkdir(parents=True, exist_ok=True)

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"FASE = {FASE} | device = {DEVICE} | torch {torch.__version__}")
# Out:
# FASE = prosodia | device = cuda | torch 2.10.0+cu128

# %%
import hashlib, importlib.util, urllib.request

EVAL_METRICS_URL = "https://raw.githubusercontent.com/asvspoof-challenge/2021/main/eval-package/eval_metrics.py"
EVAL_METRICS_PATH = OUT_DIR / "eval_metrics.py"
if not EVAL_METRICS_PATH.exists():
    urllib.request.urlretrieve(EVAL_METRICS_URL, EVAL_METRICS_PATH)
spec = importlib.util.spec_from_file_location("asvspoof_eval_metrics", EVAL_METRICS_PATH)
asv_metrics = importlib.util.module_from_spec(spec); spec.loader.exec_module(asv_metrics)
EVAL_METRICS_SHA256 = hashlib.sha256(EVAL_METRICS_PATH.read_bytes()).hexdigest()
print("eval_metrics.py | sha256", EVAL_METRICS_SHA256[:16], "...")

def compute_eer(y, s):
    y, s = np.asarray(y), np.asarray(s, dtype=np.float64)
    eer, _ = asv_metrics.compute_eer(s[y == 1], s[y == 0])
    return float(eer)

assert compute_eer([1, 1, 0, 0], [2.0, 3.0, 0.0, 1.0]) == 0.0
assert compute_eer([1, 1, 0, 0], [0.0, 1.0, 2.0, 3.0]) == 1.0
# Out:
# eval_metrics.py | sha256 70c5d2fe8fab6654 ...

# %%
COLS = ["speaker", "utt_id", "codec", "source", "attack", "label", "trim", "subset", "vocoder",
        "c9", "c10", "c11", "c12"]

keys_path = Path(DF_KEYS) if DF_KEYS else None
assert keys_path and keys_path.exists(), "Imposta DF_KEYS con il percorso di trial_metadata.txt"
meta = pd.read_csv(keys_path, sep=r"\s+", header=None, names=COLS, dtype=str, engine="python")
print(f"trial_metadata.txt: {len(meta):,} prove | sottoinsiemi {meta['subset'].value_counts().to_dict()}")

meta = meta[meta["subset"].isin(SUBSETS)].reset_index(drop=True)
meta["y_bonafide"] = (meta["label"] == "bonafide").astype(np.int8)
print(f"selezionate: {len(meta):,} prove | bona fide {int(meta['y_bonafide'].sum()):,} | "
      f"spoof {int((1 - meta['y_bonafide']).sum()):,}")

audio_root = Path(DF_AUDIO_DIR) if DF_AUDIO_DIR else None
assert audio_root and audio_root.exists(), "Imposta DF_AUDIO_DIR con la cartella dei file .flac"
t0 = time.perf_counter()
mappa = {p.stem: str(p) for p in audio_root.rglob("*.flac")}
print(f"file audio trovati: {len(mappa):,} in {time.perf_counter() - t0:.0f} s")

meta["path"] = meta["utt_id"].map(mappa)
mancanti = int(meta["path"].isna().sum())
if mancanti:
    print(f"ATTENZIONE: {mancanti:,} prove senza file audio, escluse dalla valutazione")
    meta = meta[meta["path"].notna()].reset_index(drop=True)
assert len(meta), "Nessuna prova con file audio corrispondente: controlla DF_AUDIO_DIR"
#meta = meta.iloc[:1000].copy()   solo per testing

INDEX_PATH = OUT_DIR / "index_df.csv"
meta.drop(columns=["c9", "c10", "c11", "c12"]).to_csv(INDEX_PATH, index=False)
print(f"indice scritto in {INDEX_PATH} | {len(meta):,} prove | prove escluse {mancanti:,}")
meta[["utt_id", "codec", "source", "attack", "label", "subset", "vocoder"]].head()
# Out:
# trial_metadata.txt: 611,829 prove | sottoinsiemi {'eval': 533928, 'progress': 59325, 'hidden': 18576}
# selezionate: 533,928 prove | bona fide 14,869 | spoof 519,059
# file audio trovati: 611,829 in 931 s
# indice scritto in /kaggle/working/df2021/index_df.csv | 533,928 prove | prove escluse 0
#          utt_id    codec    source        attack  label subset  \
# 0  DF_E_2000013  low_m4a   vcc2020  Task1-team20  spoof   eval
# 1  DF_E_2000024   mp3m4a   vcc2020  Task2-team12  spoof   eval
# 2  DF_E_2000026   mp3m4a  asvspoof           A09  spoof   eval
# 3  DF_E_2000027   mp3m4a  asvspoof           A12  spoof   eval
# 4  DF_E_2000028  low_mp3   vcc2018       SPO-N12  spoof   eval
#
#                             vocoder
# 0  neural_vocoder_nonautoregressive
# 1               traditional_vocoder
# 2               traditional_vocoder
# 3     neural_vocoder_autoregressive
# 4               traditional_vocoder

# %%
if FASE == "ptm":
    try:
        from transformers import WhisperModel, WhisperFeatureExtractor
    except ImportError:
        subprocess.run([sys.executable, "-m", "pip", "install", "-q", "transformers"], check=True)
        from transformers import WhisperModel, WhisperFeatureExtractor
    try:
        from speechbrain.inference.speaker import EncoderClassifier
    except ImportError:
        try:
            from speechbrain.pretrained import EncoderClassifier
        except ImportError:
            subprocess.run([sys.executable, "-m", "pip", "install", "-q", "speechbrain"], check=True)
            from speechbrain.inference.speaker import EncoderClassifier
    

    feat_extractor = WhisperFeatureExtractor.from_pretrained(WHISPER_MODEL)
    whisper = WhisperModel.from_pretrained(WHISPER_MODEL).encoder.to(DEVICE).eval()
    for p in whisper.parameters():
        p.requires_grad_(False)
    ecapa = EncoderClassifier.from_hparams(source=ECAPA_MODEL, savedir=str(OUT_DIR / "_ecapa"),
                                           run_opts={"device": DEVICE})
    ecapa.eval()
    for p in ecapa.mods.parameters():
        p.requires_grad_(False)
    print("modelli caricati")

    CONTATORI = {"risampionati": 0, "multicanale": 0}
    ERRORI = []

    def _decode(path):
        try:
            return sf.read(path, dtype="float32", always_2d=False)
        except Exception:
            import librosa
            x, sr = librosa.load(path, sr=None, mono=True)
            return x.astype(np.float32), sr

    def load_audio(path):    
        try:
            x, sr = librosa.load(path, sr=SR)
        except Exception:
            ERRORI.append(str(path))
            return np.zeros(SR, dtype=np.float32)
        if len(x) == 0:
            ERRORI.append(str(path))
            return np.zeros(SR, dtype=np.float32)
        return np.ascontiguousarray(x, dtype=np.float32)

    def n_frames_of(n_samples):
        return int(min(math.ceil(n_samples / HOP_SAMPLES), MAX_FRAMES))

    @torch.no_grad()
    def whisper_mean_batch(waves):
        feats = feat_extractor([w for w in waves], sampling_rate=SR, return_tensors="pt")
        out = whisper(feats.input_features.to(DEVICE)).last_hidden_state.float().cpu().numpy()
        # media sui soli frame reali, esattamente come nel notebook 08
        return np.stack([out[i, :n_frames_of(len(w))].mean(0) for i, w in enumerate(waves)])

    @torch.no_grad()
    def ecapa_batch(waves):
        lens = torch.tensor([len(w) for w in waves], dtype=torch.float32)
        maxlen = int(lens.max())
        batch = torch.zeros(len(waves), maxlen)
        for i, w in enumerate(waves):
            batch[i, :len(w)] = torch.from_numpy(w)
        emb = ecapa.encode_batch(batch.to(DEVICE), (lens / maxlen).to(DEVICE))
        return emb.squeeze(1).float().cpu().numpy()

    n_shards = math.ceil(len(meta) / SHARD_FILES)
    t_start = time.perf_counter()
    for k in range(n_shards):
        p_out = PTM_DIR / f"ptm_{k:04d}.npz"
        if p_out.exists():
            continue
        chunk = meta.iloc[k * SHARD_FILES:(k + 1) * SHARD_FILES]
        t0 = time.perf_counter()
        means, embs = [], []
        for i in range(0, len(chunk), WHISPER_BATCH):
            waves = [load_audio(p) for p in chunk["path"].iloc[i:i + WHISPER_BATCH]]
            means.append(whisper_mean_batch(waves))
            for j in range(0, len(waves), ECAPA_BATCH):
                embs.append(ecapa_batch(waves[j:j + ECAPA_BATCH]))
        np.savez(p_out, whisper_mean=np.concatenate(means).astype(np.float32),
                 ecapa=np.concatenate(embs).astype(np.float32),
                 utt_id=chunk["utt_id"].to_numpy())
        dt = time.perf_counter() - t0
        print(f"blocco {k + 1}/{n_shards}: {len(chunk)} file in {dt / 60:.1f} min "
              f"({dt / len(chunk) * 1000:.0f} ms/file) | residuo stimato "
              f"{dt * (n_shards - k - 1) / 60:.0f} min", flush=True)
    print(f"Fase ptm terminata in {(time.perf_counter() - t_start) / 60:.1f} min | {CONTATORI}")
    print(f"Fase ptm terminata in {(time.perf_counter() - t_start) / 60:.1f} min | {CONTATORI} | non decodificati: {len(ERRORI)}")
    if ERRORI:
        pd.Series(sorted(set(ERRORI))).to_csv(OUT_DIR / "audio_non_decodificati.csv", index=False, header=["path"])
        print("primi 5:", sorted(set(ERRORI))[:5])
else:
    print("fase 'ptm' saltata")
# Out:
# fase 'ptm' saltata

# %%
if FASE == "prosodia":
    from concurrent.futures import ProcessPoolExecutor
    try:
        import parselmouth
    except ImportError:
        subprocess.run([sys.executable, "-m", "pip", "install", "-q", "praat-parselmouth"], check=True)
        import parselmouth
    from parselmouth.praat import call

    N_WORKERS = os.cpu_count() or 1
    print(f"parselmouth {parselmouth.__version__} | Praat {parselmouth.PRAAT_VERSION} | core {N_WORKERS}")

    def make_windows(duration, w):
        starts = np.arange(0.0, duration, w)
        ends = np.minimum(starts + w, duration)
        keep = (ends - starts) >= w / 2
        return starts[keep], ends[keep]

    def window_features(snd, pp, ht, hv, it, iv, a, b, pt, f0):
        f0w = f0[(pt >= a) & (pt < b)]
        f0w = f0w[f0w > 0]
        if len(f0w) == 0:
            return np.zeros(len(FEATURES))
        out = np.full(len(FEATURES), np.nan)
        out[0] = f0w.mean()
        out[1] = f0w.std() if len(f0w) >= 2 else np.nan
        try:
            out[2] = call(pp, "Get jitter (local)", a, b, PERIOD_FLOOR, PERIOD_CEILING, MAX_PERIOD_FACTOR)
        except Exception:
            pass
        try:
            out[3] = call([snd, pp], "Get shimmer (local)", a, b, PERIOD_FLOOR, PERIOD_CEILING,
                          MAX_PERIOD_FACTOR, MAX_AMPLITUDE_FACTOR)
        except Exception:
            pass
        hw = hv[(ht >= a) & (ht < b)]; hw = hw[hw > -100]
        if len(hw):
            out[4] = hw.mean(); out[5] = hw.std() if len(hw) >= 2 else np.nan
        iw = iv[(it >= a) & (it < b)]; iw = iw[np.isfinite(iw)]
        if len(iw):
            out[6] = iw.mean(); out[7] = iw.std() if len(iw) >= 2 else np.nan
        return np.nan_to_num(out, nan=0.0)

    def process_file(path):
        try:
            snd = parselmouth.Sound(path)
            if snd.sampling_frequency != SR:
                snd = snd.resample(SR)
            harm = call(snd, "To Harmonicity (cc)", HNR_TIME_STEP, PITCH_FLOOR, HNR_SILENCE, HNR_PERIODS)
            inten = snd.to_intensity(minimum_pitch=PITCH_FLOOR)
            ht, hv = np.asarray(harm.xs()), np.asarray(harm.values[0])
            it, iv = np.asarray(inten.xs()), np.asarray(inten.values[0])
            starts, ends = make_windows(snd.duration, WINDOW_S)
            pitch = call(snd, "To Pitch (cc)", TIME_STEP, PITCH_FLOOR, MAX_CANDIDATES, VERY_ACCURATE,
                         CFG_STANDARD["silence_threshold"], VOICING_THRESHOLD, CFG_STANDARD["octave_cost"],
                         CFG_STANDARD["octave_jump_cost"], CFG_STANDARD["voiced_unvoiced_cost"], PITCH_CEILING)
            pp = call([snd, pitch], "To PointProcess (cc)")
            pt, f0 = np.asarray(pitch.xs()), np.asarray(pitch.selected_array["frequency"])
            X = np.zeros((max(len(starts), 1), len(FEATURES)), dtype=np.float32)
            for i, (a, b) in enumerate(zip(starts, ends)):
                X[i] = window_features(snd, pp, ht, hv, it, iv, a, b, pt, f0)
            return X, ""
        except Exception as e:
            return np.zeros((1, len(FEATURES)), np.float32), repr(e)

    n_chunks = math.ceil(len(meta) / CHUNK_PROS)
    t_start = time.perf_counter()
    for k in range(n_chunks):
        p_out = PROS_DIR / f"pros_{k:04d}.npz"
        if p_out.exists():
            continue
        chunk = meta.iloc[k * CHUNK_PROS:(k + 1) * CHUNK_PROS]
        t0 = time.perf_counter()
        with ProcessPoolExecutor(max_workers=N_WORKERS) as ex:
            res = list(ex.map(process_file, chunk["path"], chunksize=8))
        seqs = [r[0] for r in res]
        lens = np.array([len(x) for x in seqs], dtype=np.int64)
        np.savez(p_out, X=np.concatenate(seqs).astype(np.float32),
                 offsets=np.concatenate([[0], np.cumsum(lens)]).astype(np.int64),
                 utt_id=chunk["utt_id"].to_numpy(),
                 error=np.array([r[1] for r in res]))
        dt = time.perf_counter() - t0
        print(f"blocco {k + 1}/{n_chunks}: {len(chunk)} file in {dt / 60:.1f} min "
              f"({dt / len(chunk) * 1000:.0f} ms/file) | residuo stimato "
              f"{dt * (n_chunks - k - 1) / 60:.0f} min", flush=True)
    print(f"Fase prosodia terminata in {(time.perf_counter() - t_start) / 60:.1f} min")
else:
    print("fase 'prosodia' saltata")
# Out:
# parselmouth 0.4.7 | Praat 6.1.38 | core 4
# blocco 1/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 533 min
# blocco 2/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 516 min
# blocco 3/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 526 min
# blocco 4/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 517 min
# blocco 5/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 516 min
# blocco 6/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 522 min
# blocco 7/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 509 min
# blocco 8/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 514 min
# blocco 9/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 506 min
# blocco 10/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 513 min
# blocco 11/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 516 min
# blocco 12/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 505 min
# blocco 13/534: 1000 file in 1.0 min (57 ms/file) | residuo stimato 499 min
# blocco 14/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 508 min
# blocco 15/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 501 min
# blocco 16/534: 1000 file in 0.9 min (57 ms/file) | residuo stimato 489 min
# blocco 17/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 498 min
# blocco 18/534: 1000 file in 1.0 min (57 ms/file) | residuo stimato 491 min
# blocco 19/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 495 min
# blocco 20/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 495 min
# blocco 21/534: 1000 file in 0.9 min (56 ms/file) | residuo stimato 482 min
# blocco 22/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 504 min
# blocco 23/534: 1000 file in 1.0 min (57 ms/file) | residuo stimato 487 min
# blocco 24/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 496 min
# blocco 25/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 493 min
# blocco 26/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 487 min
# blocco 27/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 500 min
# blocco 28/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 493 min
# blocco 29/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 485 min
# blocco 30/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 484 min
# blocco 31/534: 1000 file in 0.9 min (57 ms/file) | residuo stimato 478 min
# blocco 32/534: 1000 file in 1.0 min (57 ms/file) | residuo stimato 480 min
# blocco 33/534: 1000 file in 1.0 min (57 ms/file) | residuo stimato 480 min
# blocco 34/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 496 min
# blocco 35/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 487 min
# blocco 36/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 489 min
# blocco 37/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 484 min
# blocco 38/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 476 min
# blocco 39/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 485 min
# blocco 40/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 478 min
# blocco 41/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 481 min
# blocco 42/534: 1000 file in 0.9 min (57 ms/file) | residuo stimato 466 min
# blocco 43/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 476 min
# blocco 44/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 487 min
# blocco 45/534: 1000 file in 1.0 min (57 ms/file) | residuo stimato 468 min
# blocco 46/534: 1000 file in 0.9 min (57 ms/file) | residuo stimato 461 min
# blocco 47/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 482 min
# blocco 48/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 470 min
# blocco 49/534: 1000 file in 1.0 min (57 ms/file) | residuo stimato 465 min
# blocco 50/534: 1000 file in 1.0 min (57 ms/file) | residuo stimato 464 min
# blocco 51/534: 1000 file in 0.9 min (57 ms/file) | residuo stimato 458 min
# blocco 52/534: 1000 file in 0.9 min (57 ms/file) | residuo stimato 457 min
# blocco 53/534: 1000 file in 0.9 min (57 ms/file) | residuo stimato 456 min
# blocco 54/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 462 min
# blocco 55/534: 1000 file in 1.0 min (57 ms/file) | residuo stimato 456 min
# blocco 56/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 471 min
# blocco 57/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 481 min
# blocco 58/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 474 min
# blocco 59/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 459 min
# blocco 60/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 456 min
# blocco 61/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 465 min
# blocco 62/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 468 min
# blocco 63/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 457 min
# blocco 64/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 456 min
# blocco 65/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 456 min
# blocco 66/534: 1000 file in 1.0 min (57 ms/file) | residuo stimato 447 min
# blocco 67/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 461 min
# blocco 68/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 453 min
# blocco 69/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 450 min
# blocco 70/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 456 min
# blocco 71/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 453 min
# blocco 72/534: 1000 file in 1.0 min (57 ms/file) | residuo stimato 443 min
# blocco 73/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 464 min
# blocco 74/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 448 min
# blocco 75/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 445 min
# blocco 76/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 441 min
# blocco 77/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 445 min
# blocco 78/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 442 min
# blocco 79/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 446 min
# blocco 80/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 450 min
# blocco 81/534: 1000 file in 0.9 min (57 ms/file) | residuo stimato 428 min
# blocco 82/534: 1000 file in 0.9 min (57 ms/file) | residuo stimato 427 min
# blocco 83/534: 1000 file in 0.9 min (57 ms/file) | residuo stimato 428 min
# blocco 84/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 445 min
# blocco 85/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 455 min
# blocco 86/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 454 min
# blocco 87/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 430 min
# blocco 88/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 438 min
# blocco 89/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 444 min
# blocco 90/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 445 min
# blocco 91/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 436 min
# blocco 92/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 444 min
# blocco 93/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 434 min
# blocco 94/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 439 min
# blocco 95/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 427 min
# blocco 96/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 434 min
# blocco 97/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 435 min
# blocco 98/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 429 min
# blocco 99/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 434 min
# blocco 100/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 426 min
# blocco 101/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 436 min
# blocco 102/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 435 min
# blocco 103/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 438 min
# blocco 104/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 422 min
# blocco 105/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 420 min
# blocco 106/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 426 min
# blocco 107/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 416 min
# blocco 108/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 420 min
# blocco 109/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 422 min
# blocco 110/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 429 min
# blocco 111/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 428 min
# blocco 112/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 434 min
# blocco 113/534: 1000 file in 1.0 min (63 ms/file) | residuo stimato 439 min
# blocco 114/534: 1000 file in 1.1 min (65 ms/file) | residuo stimato 455 min
# blocco 115/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 432 min
# blocco 116/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 432 min
# blocco 117/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 431 min
# blocco 118/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 422 min
# blocco 119/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 429 min
# blocco 120/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 417 min
# blocco 121/534: 1000 file in 1.0 min (63 ms/file) | residuo stimato 434 min
# blocco 122/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 416 min
# blocco 123/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 412 min
# blocco 124/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 407 min
# blocco 125/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 407 min
# blocco 126/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 413 min
# blocco 127/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 411 min
# blocco 128/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 416 min
# blocco 129/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 408 min
# blocco 130/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 416 min
# blocco 131/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 405 min
# blocco 132/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 401 min
# blocco 133/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 411 min
# blocco 134/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 415 min
# blocco 135/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 397 min
# blocco 136/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 401 min
# blocco 137/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 401 min
# blocco 138/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 395 min
# blocco 139/534: 1000 file in 1.1 min (63 ms/file) | residuo stimato 415 min
# blocco 140/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 405 min
# blocco 141/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 396 min
# blocco 142/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 389 min
# blocco 143/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 399 min
# blocco 144/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 388 min
# blocco 145/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 392 min
# blocco 146/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 401 min
# blocco 147/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 402 min
# blocco 148/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 399 min
# blocco 149/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 393 min
# blocco 150/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 396 min
# blocco 151/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 393 min
# blocco 152/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 385 min
# blocco 153/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 385 min
# blocco 154/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 381 min
# blocco 155/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 381 min
# blocco 156/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 384 min
# blocco 157/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 385 min
# blocco 158/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 380 min
# blocco 159/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 377 min
# blocco 160/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 380 min
# blocco 161/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 373 min
# blocco 162/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 371 min
# blocco 163/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 373 min
# blocco 164/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 365 min
# blocco 165/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 368 min
# blocco 166/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 370 min
# blocco 167/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 371 min
# blocco 168/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 371 min
# blocco 169/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 366 min
# blocco 170/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 357 min
# blocco 171/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 356 min
# blocco 172/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 368 min
# blocco 173/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 359 min
# blocco 174/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 361 min
# blocco 175/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 364 min
# blocco 176/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 355 min
# blocco 177/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 366 min
# blocco 178/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 357 min
# blocco 179/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 347 min
# blocco 180/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 366 min
# blocco 181/534: 1000 file in 1.1 min (64 ms/file) | residuo stimato 377 min
# blocco 182/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 353 min
# blocco 183/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 351 min
# blocco 184/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 353 min
# blocco 185/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 348 min
# blocco 186/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 349 min
# blocco 187/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 348 min
# blocco 188/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 338 min
# blocco 189/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 348 min
# blocco 190/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 332 min
# blocco 191/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 348 min
# blocco 192/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 354 min
# blocco 193/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 334 min
# blocco 194/534: 1000 file in 1.0 min (63 ms/file) | residuo stimato 357 min
# blocco 195/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 340 min
# blocco 196/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 331 min
# blocco 197/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 342 min
# blocco 198/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 333 min
# blocco 199/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 335 min
# blocco 200/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 329 min
# blocco 201/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 333 min
# blocco 202/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 330 min
# blocco 203/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 336 min
# blocco 204/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 335 min
# blocco 205/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 330 min
# blocco 206/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 324 min
# blocco 207/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 325 min
# blocco 208/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 325 min
# blocco 209/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 329 min
# blocco 210/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 316 min
# blocco 211/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 319 min
# blocco 212/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 318 min
# blocco 213/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 317 min
# blocco 214/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 319 min
# blocco 215/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 318 min
# blocco 216/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 309 min
# blocco 217/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 316 min
# blocco 218/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 320 min
# blocco 219/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 308 min
# blocco 220/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 310 min
# blocco 221/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 312 min
# blocco 222/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 305 min
# blocco 223/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 305 min
# blocco 224/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 311 min
# blocco 225/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 312 min
# blocco 226/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 309 min
# blocco 227/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 306 min
# blocco 228/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 300 min
# blocco 229/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 298 min
# blocco 230/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 295 min
# blocco 231/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 296 min
# blocco 232/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 295 min
# blocco 233/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 291 min
# blocco 234/534: 1000 file in 1.0 min (57 ms/file) | residuo stimato 287 min
# blocco 235/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 293 min
# blocco 236/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 289 min
# blocco 237/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 291 min
# blocco 238/534: 1000 file in 0.9 min (57 ms/file) | residuo stimato 281 min
# blocco 239/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 294 min
# blocco 240/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 285 min
# blocco 241/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 283 min
# blocco 242/534: 1000 file in 1.0 min (57 ms/file) | residuo stimato 278 min
# blocco 243/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 281 min
# blocco 244/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 288 min
# blocco 245/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 283 min
# blocco 246/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 284 min
# blocco 247/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 277 min
# blocco 248/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 286 min
# blocco 249/534: 1000 file in 1.0 min (63 ms/file) | residuo stimato 297 min
# blocco 250/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 286 min
# blocco 251/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 276 min
# blocco 252/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 274 min
# blocco 253/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 271 min
# blocco 254/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 273 min
# blocco 255/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 277 min
# blocco 256/534: 1000 file in 0.9 min (57 ms/file) | residuo stimato 264 min
# blocco 257/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 274 min
# blocco 258/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 277 min
# blocco 259/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 272 min
# blocco 260/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 270 min
# blocco 261/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 270 min
# blocco 262/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 267 min
# blocco 263/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 266 min
# blocco 264/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 260 min
# blocco 265/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 268 min
# blocco 266/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 264 min
# blocco 267/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 265 min
# blocco 268/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 262 min
# blocco 269/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 265 min
# blocco 270/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 261 min
# blocco 271/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 269 min
# blocco 272/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 260 min
# blocco 273/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 257 min
# blocco 274/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 264 min
# blocco 275/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 262 min
# blocco 276/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 260 min
# blocco 277/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 264 min
# blocco 278/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 258 min
# blocco 279/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 265 min
# blocco 280/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 255 min
# blocco 281/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 246 min
# blocco 282/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 252 min
# blocco 283/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 243 min
# blocco 284/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 248 min
# blocco 285/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 245 min
# blocco 286/534: 1000 file in 1.0 min (57 ms/file) | residuo stimato 237 min
# blocco 287/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 243 min
# blocco 288/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 243 min
# blocco 289/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 244 min
# blocco 290/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 238 min
# blocco 291/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 237 min
# blocco 292/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 241 min
# blocco 293/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 239 min
# blocco 294/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 233 min
# blocco 295/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 239 min
# blocco 296/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 231 min
# blocco 297/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 234 min
# blocco 298/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 231 min
# blocco 299/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 231 min
# blocco 300/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 231 min
# blocco 301/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 229 min
# blocco 302/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 224 min
# blocco 303/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 224 min
# blocco 304/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 225 min
# blocco 305/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 225 min
# blocco 306/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 226 min
# blocco 307/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 223 min
# blocco 308/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 225 min
# blocco 309/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 224 min
# blocco 310/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 225 min
# blocco 311/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 219 min
# blocco 312/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 221 min
# blocco 313/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 220 min
# blocco 314/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 215 min
# blocco 315/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 217 min
# blocco 316/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 222 min
# blocco 317/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 217 min
# blocco 318/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 216 min
# blocco 319/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 216 min
# blocco 320/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 215 min
# blocco 321/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 215 min
# blocco 322/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 209 min
# blocco 323/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 205 min
# blocco 324/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 208 min
# blocco 325/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 204 min
# blocco 326/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 203 min
# blocco 327/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 204 min
# blocco 328/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 200 min
# blocco 329/534: 1000 file in 0.9 min (57 ms/file) | residuo stimato 195 min
# blocco 330/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 203 min
# blocco 331/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 201 min
# blocco 332/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 194 min
# blocco 333/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 200 min
# blocco 334/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 196 min
# blocco 335/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 195 min
# blocco 336/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 194 min
# blocco 337/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 194 min
# blocco 338/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 196 min
# blocco 339/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 191 min
# blocco 340/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 190 min
# blocco 341/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 188 min
# blocco 342/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 193 min
# blocco 343/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 190 min
# blocco 344/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 191 min
# blocco 345/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 191 min
# blocco 346/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 188 min
# blocco 347/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 188 min
# blocco 348/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 184 min
# blocco 349/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 177 min
# blocco 350/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 180 min
# blocco 351/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 179 min
# blocco 352/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 177 min
# blocco 353/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 175 min
# blocco 354/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 177 min
# blocco 355/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 176 min
# blocco 356/534: 1000 file in 1.0 min (57 ms/file) | residuo stimato 171 min
# blocco 357/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 173 min
# blocco 358/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 175 min
# blocco 359/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 175 min
# blocco 360/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 169 min
# blocco 361/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 169 min
# blocco 362/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 170 min
# blocco 363/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 171 min
# blocco 364/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 171 min
# blocco 365/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 169 min
# blocco 366/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 164 min
# blocco 367/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 170 min
# blocco 368/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 167 min
# blocco 369/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 165 min
# blocco 370/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 162 min
# blocco 371/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 167 min
# blocco 372/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 167 min
# blocco 373/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 159 min
# blocco 374/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 161 min
# blocco 375/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 157 min
# blocco 376/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 153 min
# blocco 377/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 155 min
# blocco 378/534: 1000 file in 0.9 min (57 ms/file) | residuo stimato 148 min
# blocco 379/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 152 min
# blocco 380/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 152 min
# blocco 381/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 149 min
# blocco 382/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 151 min
# blocco 383/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 150 min
# blocco 384/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 146 min
# blocco 385/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 148 min
# blocco 386/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 146 min
# blocco 387/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 141 min
# blocco 388/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 142 min
# blocco 389/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 139 min
# blocco 390/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 142 min
# blocco 391/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 139 min
# blocco 392/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 137 min
# blocco 393/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 136 min
# blocco 394/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 137 min
# blocco 395/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 134 min
# blocco 396/534: 1000 file in 1.0 min (57 ms/file) | residuo stimato 132 min
# blocco 397/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 133 min
# blocco 398/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 134 min
# blocco 399/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 134 min
# blocco 400/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 136 min
# blocco 401/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 130 min
# blocco 402/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 132 min
# blocco 403/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 129 min
# blocco 404/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 127 min
# blocco 405/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 128 min
# blocco 406/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 129 min
# blocco 407/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 125 min
# blocco 408/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 124 min
# blocco 409/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 123 min
# blocco 410/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 122 min
# blocco 411/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 119 min
# blocco 412/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 121 min
# blocco 413/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 120 min
# blocco 414/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 119 min
# blocco 415/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 118 min
# blocco 416/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 118 min
# blocco 417/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 115 min
# blocco 418/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 115 min
# blocco 419/534: 1000 file in 1.1 min (64 ms/file) | residuo stimato 122 min
# blocco 420/534: 1000 file in 1.1 min (63 ms/file) | residuo stimato 120 min
# blocco 421/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 116 min
# blocco 422/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 113 min
# blocco 423/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 109 min
# blocco 424/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 109 min
# blocco 425/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 110 min
# blocco 426/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 106 min
# blocco 427/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 107 min
# blocco 428/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 106 min
# blocco 429/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 106 min
# blocco 430/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 104 min
# blocco 431/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 104 min
# blocco 432/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 103 min
# blocco 433/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 102 min
# blocco 434/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 100 min
# blocco 435/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 101 min
# blocco 436/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 97 min
# blocco 437/534: 1000 file in 1.0 min (63 ms/file) | residuo stimato 102 min
# blocco 438/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 96 min
# blocco 439/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 97 min
# blocco 440/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 95 min
# blocco 441/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 91 min
# blocco 442/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 93 min
# blocco 443/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 92 min
# blocco 444/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 90 min
# blocco 445/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 90 min
# blocco 446/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 89 min
# blocco 447/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 88 min
# blocco 448/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 88 min
# blocco 449/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 85 min
# blocco 450/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 85 min
# blocco 451/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 84 min
# blocco 452/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 82 min
# blocco 453/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 81 min
# blocco 454/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 81 min
# blocco 455/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 80 min
# blocco 456/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 78 min
# blocco 457/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 76 min
# blocco 458/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 75 min
# blocco 459/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 75 min
# blocco 460/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 72 min
# blocco 461/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 72 min
# blocco 462/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 74 min
# blocco 463/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 71 min
# blocco 464/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 70 min
# blocco 465/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 69 min
# blocco 466/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 69 min
# blocco 467/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 67 min
# blocco 468/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 67 min
# blocco 469/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 66 min
# blocco 470/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 63 min
# blocco 471/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 62 min
# blocco 472/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 61 min
# blocco 473/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 61 min
# blocco 474/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 61 min
# blocco 475/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 59 min
# blocco 476/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 58 min
# blocco 477/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 57 min
# blocco 478/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 57 min
# blocco 479/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 55 min
# blocco 480/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 53 min
# blocco 481/534: 1000 file in 1.0 min (62 ms/file) | residuo stimato 54 min
# blocco 482/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 52 min
# blocco 483/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 50 min
# blocco 484/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 50 min
# blocco 485/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 49 min
# blocco 486/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 47 min
# blocco 487/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 47 min
# blocco 488/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 46 min
# blocco 489/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 43 min
# blocco 490/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 43 min
# blocco 491/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 43 min
# blocco 492/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 42 min
# blocco 493/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 42 min
# blocco 494/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 40 min
# blocco 495/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 39 min
# blocco 496/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 38 min
# blocco 497/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 37 min
# blocco 498/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 36 min
# blocco 499/534: 1000 file in 1.0 min (58 ms/file) | residuo stimato 34 min
# blocco 500/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 34 min
# blocco 501/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 34 min
# blocco 502/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 32 min
# blocco 503/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 30 min
# blocco 504/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 30 min
# blocco 505/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 29 min
# blocco 506/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 28 min
# blocco 507/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 27 min
# blocco 508/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 26 min
# blocco 509/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 25 min
# blocco 510/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 25 min
# blocco 511/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 23 min
# blocco 512/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 22 min
# blocco 513/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 21 min
# blocco 514/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 20 min
# blocco 515/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 19 min
# blocco 516/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 18 min
# blocco 517/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 17 min
# blocco 518/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 16 min
# blocco 519/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 15 min
# blocco 520/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 14 min
# blocco 521/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 13 min
# blocco 522/534: 1000 file in 1.0 min (59 ms/file) | residuo stimato 12 min
# blocco 523/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 11 min
# blocco 524/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 10 min
# blocco 525/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 9 min
# blocco 526/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 8 min
# blocco 527/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 7 min
# blocco 528/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 6 min
# blocco 529/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 5 min
# blocco 530/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 4 min
# blocco 531/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 3 min
# blocco 532/534: 1000 file in 1.0 min (60 ms/file) | residuo stimato 2 min
# blocco 533/534: 1000 file in 1.0 min (61 ms/file) | residuo stimato 1 min
# blocco 534/534: 928 file in 0.9 min (60 ms/file) | residuo stimato 0 min
# Fase prosodia terminata in 529.7 min

# %%
if FASE == "inferenza":
    index = pd.read_csv(INDEX_PATH, dtype=str)
    index["y_bonafide"] = index["y_bonafide"].astype(np.int8)
    utt_ref = index["utt_id"].to_numpy()
    pos = {u: i for i, u in enumerate(utt_ref)}
    N = len(index)

    # --- caratteristiche a livello di file -------------------------------------
    shards = sorted(PTM_DIR.glob("ptm_*.npz"))
    assert shards, f"Nessun blocco in {PTM_DIR}: esegui prima FASE = 'ptm'"
    WMEAN = np.full((N, D_WHISPER), np.nan, dtype=np.float32)
    ECAP  = np.full((N, D_ECAPA),  np.nan, dtype=np.float32)
    for p in shards:
        z = np.load(p, allow_pickle=True)
        idx = np.array([pos[u] for u in z["utt_id"]])
        WMEAN[idx] = z["whisper_mean"]; ECAP[idx] = z["ecapa"]
    manca = int(np.isnan(WMEAN[:, 0]).sum())
    assert manca == 0, f"{manca} prove senza caratteristiche PTM: la fase 'ptm' non e' completa"
    assert np.isfinite(WMEAN).all() and np.isfinite(ECAP).all()

    # --- caratteristiche prosodiche --------------------------------------------
    shards = sorted(PROS_DIR.glob("pros_*.npz"))
    assert shards, f"Nessun blocco in {PROS_DIR}: esegui prima FASE = 'prosodia'"
    seqs = [None] * N
    n_err = 0
    for p in shards:
        z = np.load(p, allow_pickle=True)
        X, off, utt = z["X"], z["offsets"].astype(np.int64), z["utt_id"]
        n_err += int((z["error"] != "").sum())
        for j, u in enumerate(utt):
            seqs[pos[u]] = X[off[j]:off[j + 1]]
    manca = sum(s is None for s in seqs)
    assert manca == 0, f"{manca} prove senza caratteristiche prosodiche: la fase 'prosodia' non e' completa"
    if n_err:
        print(f"ATTENZIONE: {n_err} file con errore di elaborazione Praat, sostituiti da una finestra nulla")
    print(f"caricate {N:,} prove | finestre prosodiche mediana "
          f"{np.median([len(s) for s in seqs]):.0f}")

    # --- preprocessing, con le statistiche dell'addestramento -------------------
    PP = json.loads(Path(PREPROC_PROSODIA).read_text())
    ST = json.loads(Path(STANDARDIZER).read_text())
    assert len(PP["clip_lo"]) == 16, "preproc_prosody.json non corrisponde alla variante D (16 canali)"
    clip_lo, clip_hi = np.array(PP["clip_lo"], np.float32), np.array(PP["clip_hi"], np.float32)
    mm_lo, mm_rng = np.array(PP["minmax_lo"], np.float32), np.array(PP["minmax_range"], np.float32)

    def voiced_mask(x):
        return np.abs(x).sum(1) > 0

    def dynamic_features(x):
        v = voiced_mask(x); n = len(x)
        d_ok = np.zeros(n, dtype=bool); d_ok[1:] = v[1:] & v[:-1]
        d = np.zeros_like(x); d[d_ok] = x[d_ok] - x[np.where(d_ok)[0] - 1]
        return d, d_ok

    # verifica delle definizioni, identica ai notebook 06 e 10
    _x = np.array([[180.], [195.], [170.], [0.], [175.], [190.], [185.]], dtype=np.float32)
    assert dynamic_features(_x)[0][:, 0].tolist() == [0, 15, -25, 0, 0, 15, -5]

    proc = []
    for x in seqs:
        d, d_ok = dynamic_features(x)
        xd = np.concatenate([x, d], axis=1)
        m = np.concatenate([np.repeat(voiced_mask(x)[:, None], x.shape[1], 1),
                            np.repeat(d_ok[:, None], x.shape[1], 1)], axis=1)
        xc = np.where(m, np.clip(xd, clip_lo, clip_hi), xd)
        proc.append(((xc - mm_lo) / mm_rng).astype(np.float32))
    LEN_P = np.array([len(x) for x in proc], dtype=np.int64)
    OFF_P = np.concatenate([[0], np.cumsum(LEN_P)]).astype(np.int64)
    XP = np.concatenate(proc).astype(np.float32)
    del proc, seqs

    WMEAN = (WMEAN - np.array(ST["whisper_file_mean"], np.float32)) / np.array(ST["whisper_file_std"], np.float32)
    ECAP  = (ECAP  - np.array(ST["ecapa_mean"], np.float32))        / np.array(ST["ecapa_std"], np.float32)

    Y = index["y_bonafide"].to_numpy().astype(np.float32)
    print(f"prosodia: {XP.shape} | whisper file: {WMEAN.shape} | ecapa: {ECAP.shape}")
    print(f"bona fide {int(Y.sum()):,} | spoof {int((1 - Y).sum()):,}")
else:
    PTM_DIR = OUT_DIR / "ptm"
    PROS_DIR = OUT_DIR / "prosodia"
    print("fase 'inferenza' saltata")
# Out:
# fase 'inferenza' saltata

# %%
def masked_bn(x, mask, bn):
    y = torch.zeros_like(x)
    y[mask] = bn(x[mask])
    return y

def map_packed(p, fn):
    return PackedSequence(fn(p.data), p.batch_sizes, p.sorted_indices, p.unsorted_indices)

class SeqBranch(nn.Module):
    # spina dorsale sequenziale dei notebook 06, 09 e 10 (li' chiamata ProsodyBranch / WhisperBranch)
    def __init__(self, n_in, p=DROPOUT):
        super().__init__()
        self.conv1, self.bn_c1 = nn.Conv1d(n_in, 256, kernel_size=3, padding=1), nn.BatchNorm1d(256)
        self.conv2, self.bn_c2 = nn.Conv1d(256, 128, kernel_size=3, padding=1), nn.BatchNorm1d(128)
        self.drop = nn.Dropout(p)
        self.lstm1, self.bn_l1 = nn.LSTM(128, 100, batch_first=True), nn.BatchNorm1d(100)
        self.lstm2, self.bn_l2 = nn.LSTM(100, 50, batch_first=True), nn.BatchNorm1d(50)
        self.att_w, self.att_v = nn.Linear(50, 50), nn.Linear(50, 1, bias=False)
        self.out_dim = EMB_DIM

    def conv_block(self, h, conv, bn, mask):
        h = conv(h.transpose(1, 2)).transpose(1, 2)
        h = F.relu(masked_bn(h, mask, bn))
        return self.drop(h) * mask.unsqueeze(-1)

    def forward(self, x, lengths):
        T = x.shape[1]
        mask = torch.arange(T, device=x.device)[None, :] < lengths.to(x.device)[:, None]
        h = self.conv_block(x, self.conv1, self.bn_c1, mask)
        h = self.conv_block(h, self.conv2, self.bn_c2, mask)
        p = pack_padded_sequence(h, lengths.cpu(), batch_first=True, enforce_sorted=False)
        p, _ = self.lstm1(p)
        p = map_packed(map_packed(p, self.bn_l1), self.drop)
        p, _ = self.lstm2(p)
        p = map_packed(p, self.bn_l2)
        H, _ = pad_packed_sequence(p, batch_first=True, total_length=T)
        e = self.att_v(torch.tanh(self.att_w(H))).squeeze(-1)
        a = torch.softmax(e.masked_fill(~mask, float("-inf")), dim=1)
        return (a.unsqueeze(-1) * H).sum(1), a

class FileBranch(nn.Module):
    def __init__(self, n_in, p=DROPOUT):
        super().__init__()
        self.net = nn.Sequential(nn.Linear(n_in, 128), nn.BatchNorm1d(128), nn.ReLU(),
                                 nn.Dropout(p), nn.Linear(128, EMB_DIM))
        self.out_dim = EMB_DIM
    def forward(self, x):
        return self.net(x)

class ProsodyClassifier(nn.Module):
    # notebook 06.1: chiavi branch.* e head.*
    def __init__(self, n_in, p=DROPOUT):
        super().__init__()
        self.branch = SeqBranch(n_in, p)
        self.head = nn.Sequential(nn.Linear(EMB_DIM, 50), nn.ReLU(), nn.Dropout(p), nn.Linear(50, 1))
    def forward(self, xp, lp, xm, xe):
        z, _ = self.branch(xp, lp)
        return self.head(z).squeeze(-1)

class DetectorPTM(nn.Module):
    # notebook 09, varianti a ramo singolo a livello di file: chiavi eb.* oppure wfb.* e head.*
    def __init__(self, ramo, p=DROPOUT):
        super().__init__()
        assert ramo in ("E", "Wf")
        self.ramo = ramo
        if ramo == "E":
            self.eb = FileBranch(D_ECAPA, p)
        else:
            self.wfb = FileBranch(D_WHISPER, p)
        self.head = nn.Sequential(nn.Linear(EMB_DIM, 50), nn.ReLU(), nn.Dropout(p), nn.Linear(50, 1))
    def forward(self, xp, lp, xm, xe):
        z = self.eb(xe) if self.ramo == "E" else self.wfb(xm)
        return self.head(z).squeeze(-1)

class DetectorFull(nn.Module):
    # notebook 10, variante PWfE: chiavi pb.*, wfb.*, eb.*, bn_fuse.* e head.*
    def __init__(self, n_in_p, p=DROPOUT):
        super().__init__()
        self.pb  = SeqBranch(n_in_p, p)
        self.wfb = FileBranch(D_WHISPER, p)
        self.eb  = FileBranch(D_ECAPA, p)
        self.bn_fuse = nn.ModuleList([nn.BatchNorm1d(EMB_DIM) for _ in range(3)])
        self.head = nn.Sequential(nn.Linear(3 * EMB_DIM, 50), nn.ReLU(), nn.Dropout(p), nn.Linear(50, 1))
    def forward(self, xp, lp, xm, xe):
        zp, _ = self.pb(xp, lp)
        parts = [zp, self.wfb(xm), self.eb(xe)]
        parts = [bn(z) for bn, z in zip(self.bn_fuse, parts)]
        return self.head(torch.cat(parts, dim=1)).squeeze(-1)

def costruisci(nome):
    if nome == "P":    return ProsodyClassifier(2 * len(FEATURES))
    if nome == "E":    return DetectorPTM("E")
    if nome == "Wf":   return DetectorPTM("Wf")
    if nome == "PWfE": return DetectorFull(2 * len(FEATURES))
    raise ValueError(nome)

for nome in ["P", "Wf", "E", "PWfE"]:
    m = costruisci(nome)
    print(f"{nome:5s} {sum(p.numel() for p in m.parameters()):,} parametri")
del m
# Out:
# P     239,645 parametri
# Wf    74,971 parametri
# E     34,011 parametri
# PWfE  348,725 parametri

# %%
if FASE == "inferenza":
    def batch_tensors(idx):
        L = LEN_P[idx]
        Bp = torch.zeros(len(idx), int(L.max()), 2 * len(FEATURES))
        for k, i in enumerate(idx):
            n = int(LEN_P[i])
            Bp[k, :n] = torch.from_numpy(XP[OFF_P[i]:OFF_P[i] + n])
        return (Bp, torch.from_numpy(L),
                torch.from_numpy(WMEAN[idx]), torch.from_numpy(ECAP[idx]))

    @torch.no_grad()
    def punteggi(model):
        model.eval()
        out = []
        for k in range(0, len(Y), EVAL_BATCH):
            idx = np.arange(k, min(k + EVAL_BATCH, len(Y)))
            Bp, Lp, Bm, Be = batch_tensors(idx)
            out.append(model(Bp.to(DEVICE), Lp, Bm.to(DEVICE), Be.to(DEVICE)).cpu().numpy())
            if (k // EVAL_BATCH) % 200 == 0:
                print(f"  {k:,}/{len(Y):,}", flush=True)
        return np.concatenate(out)

    SCORES = {}
    for nome in ["P", "Wf", "E", "PWfE"]:
        f_sc = OUT_DIR / f"scores_df_{nome}.npy"
        if f_sc.exists():
            SCORES[nome] = np.load(f_sc); print(f"{nome}: punteggi gia' presenti, saltato"); continue
        ck = CKPT.get(nome)
        if not ck or not Path(ck).exists():
            print(f"{nome}: checkpoint non impostato o inesistente, configurazione saltata"); continue
        t0 = time.perf_counter()
        model = costruisci(nome).to(DEVICE)
        stato = torch.load(ck, map_location=DEVICE)
        model.load_state_dict(stato, strict=True)      # si ferma se i nomi non corrispondono
        s = punteggi(model)
        np.save(f_sc, s); SCORES[nome] = s
        print(f"{nome}: EER {100 * compute_eer(Y, s):.2f}% | AUC {roc_auc_score(Y, s):.4f} | "
              f"{(time.perf_counter() - t0) / 60:.1f} min")
        del model
        if DEVICE == "cuda":
            torch.cuda.empty_cache()
    print("configurazioni valutate:", list(SCORES))

# %%
if FASE == "inferenza" and SCORES:
    NOMI = [n for n in ["P", "Wf", "E", "PWfE"] if n in SCORES]

    glob = pd.DataFrame([
        {
            "configurazione": n,
            "eer_%": 100 * compute_eer(Y, SCORES[n]),
            "auc": roc_auc_score(Y, SCORES[n])
        }
        for n in NOMI
    ]).set_index("configurazione")

    print("=== EER complessivo sul DF ===")
    display(glob.round({"eer_%": 2, "auc": 4}))

    def per_gruppo(colonna, solo_spoof):
        righe = []

        for g in sorted(index[colonna].unique()):
            if solo_spoof and g in ("-", "bonafide"):
                continue

            m = (index[colonna] == g).to_numpy()

            if solo_spoof:
                m = m | (Y == 1)

            nb, ns = int(Y[m].sum()), int((1 - Y[m]).sum())

            if min(nb, ns) < MIN_PER_CLASSE:
                continue

            r = {
                colonna: g,
                "n": int(m.sum()),
                "bona_fide": nb
            }

            for n in NOMI:
                r[n] = round(
                    100 * compute_eer(Y[m], SCORES[n][m]),
                    2
                )

            righe.append(r)

        # Caso in cui nessun gruppo supera MIN_PER_CLASSE
        if not righe:
            return pd.DataFrame(
                columns=[colonna, "n", "bona_fide"] + NOMI
            ).set_index(colonna)

        return pd.DataFrame(righe).set_index(colonna)

    tabelle = {}

    for col, solo_spoof, titolo in [
        ("codec", False, "condizione di compressione"),
        ("source", False, "sorgente dei dati"),
        ("vocoder", True, "tipo di vocoder"),
        ("attack", True, "attacco")
    ]:
        t = per_gruppo(col, solo_spoof)

        if len(t):
            tabelle[col] = t

            print(f"\n=== EER (%) per {titolo} ===")
            display(t if col != "attack" else t.head(30))

            if col == "attack" and len(t) > 30:
                print(
                    f"(mostrati i primi 30 di {len(t)} attacchi; "
                    "la tabella completa e' nel file CSV)"
                )

            t.to_csv(OUT_DIR / f"eer_per_{col}.csv")

    glob.to_csv(OUT_DIR / "eer_globale.csv")

# %%
if FASE == "inferenza" and SCORES:
    from scipy.stats import norm
    _trapz = getattr(np, "trapezoid", None) or np.trapz
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    for k, n in enumerate(NOMI):
        s_ = SCORES[n].astype(np.float64)
        frr, far, _ = asv_metrics.compute_det_curve(s_[Y == 1], s_[Y == 0])
        fpr, tpr = far[::-1], (1 - frr)[::-1]
        auc_sk = roc_auc_score(Y, s_)
        assert abs(float(_trapz(tpr, fpr)) - auc_sk) < 1e-3
        axes[0].plot(fpr, tpr, color=f"C{k}", label=f"{n} (AUC {auc_sk:.4f})")
        fa, fr = np.clip(far, 1e-4, 1 - 1e-4), np.clip(frr, 1e-4, 1 - 1e-4)
        axes[1].plot(norm.ppf(fa), norm.ppf(fr), color=f"C{k}",
                     label=f"{n} (EER {100 * compute_eer(Y, s_):.2f}%)")
    axes[0].plot([0, 1], [0, 1], "k:", lw=1)
    axes[0].set_xlabel("spoof accettati (FPR)"); axes[0].set_ylabel("bona fide riconosciuti (TPR)")
    axes[0].set_title("ROC - ASVspoof 2021 DF")
    ticks = np.array([0.001, 0.01, 0.05, 0.2, 0.5, 0.8])
    for setter in (axes[1].set_xticks, axes[1].set_yticks):
        setter(norm.ppf(ticks))
    axes[1].set_xticklabels([f"{100 * t:g}" for t in ticks])
    axes[1].set_yticklabels([f"{100 * t:g}" for t in ticks])
    lim = norm.ppf([0.0005, 0.9])
    axes[1].plot(lim, lim, "k:", lw=1); axes[1].set_xlim(lim); axes[1].set_ylim(lim)
    axes[1].set_xlabel("spoof accettati (%)"); axes[1].set_ylabel("bona fide rifiutati (%)")
    axes[1].set_title("DET - ASVspoof 2021 DF")
    for ax in axes:
        ax.grid(alpha=0.3); ax.legend()
    plt.tight_layout(); plt.savefig(OUT_DIR / "roc_det_df.png", dpi=120); plt.show()

# %%
if FASE == "inferenza" and SCORES:
    summary_out = {
        "dataset": "ASVspoof 2021 DF", "subsets": SUBSETS,
        "n_trials": int(len(index)), "n_bonafide": int(Y.sum()), "n_spoof": int((1 - Y).sum()),
        "trial_metadata": str(keys_path), "audio_dir": str(audio_root),
        "configurazioni": {n: str(CKPT[n]) for n in NOMI},
        "descrizione": {"P": "solo ramo prosodico, variante D (8 feature + delta)",
                        "Wf": "solo ramo Whisper a livello di file (media sui frame reali, 512)",
                        "E": "solo ramo ECAPA-TDNN a livello di file (192)",
                        "PWfE": "fusione tardiva dei tre rami"},
        "preprocessing": {"prosodia": str(PREPROC_PROSODIA), "standardizer": str(STANDARDIZER),
                          "nota": "statistiche dell'addestramento su ASVspoof 2019 LA, non ricalcolate sul DF"},
        "eer_globale_%": glob.round(4).reset_index().to_dict("records"),
        **{f"eer_per_{k}_%": v.reset_index().to_dict("records") for k, v in tabelle.items()},
        "eer_function": {"source": EVAL_METRICS_URL, "sha256": EVAL_METRICS_SHA256},
        "auc_function": "sklearn.metrics.roc_auc_score (metrica non ASVspoof, complementare)",
        "limiti": [
            "i quattro modelli non condividono il criterio di selezione del checkpoint: PWfE e' stato "
            "scelto sull'EER di sviluppo, P, Wf ed E sulla funzione di costo di sviluppo. Il confronto "
            "e' informativo e non controllato",
            "un solo seme di inizializzazione per ciascuna configurazione: nessuna stima della "
            "variabilita' di addestramento",
            "i modelli sono addestrati su audio non compresso con sei attacchi; il DF contiene nove "
            "condizioni di compressione, 110 attacchi e materiale proveniente da corpora diversi",
        ]}
    _ = (OUT_DIR / "summary_df.json").write_text(json.dumps(summary_out, indent=2, default=float))
    print("Output:", sorted(p.name for p in OUT_DIR.iterdir() if p.is_file()))
